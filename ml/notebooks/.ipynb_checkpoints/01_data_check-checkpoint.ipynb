# %%
import pandas as pd

df = pd.read_csv("../data/raw/gdp.csv")

df = df.iloc[4:]
df = df[df["Country Name"] == "Sri Lanka"]

df = df.drop(columns=["Country Code", "Indicator Name", "Indicator Code"])

df_long = df.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")

df_long = df_long.rename(columns={"Country Name": "Country"})

df_long = df_long.dropna()

df_long["Year"] = df_long["Year"].astype(int)

df_long.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\softwares\Files\Python\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
# --> 167 'Could not get source, probably due dynamically evaluated source code.'
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
# --> 196 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7081 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7089 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Country Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 6
#       2
#       3 df = pd.read_csv("../data/raw/gdp.csv")
#       4
#       5 df = df.iloc[4:]
# ----> 6 df = df[df["Country Name"] == "Sri Lanka"]
#       7
#       8 df = df.drop(columns=["Country Code", "Indicator Name", "Indicator Code"])
#       9
#
# File D:\softwares\Files\Python\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4098
#    4099         if is_single_key:
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#    4105         else:
#
# File D:\softwares\Files\Python\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Country Name'

# %%
import pandas as pd

df = pd.read_csv("../data/raw/gdp.csv")

print(df.columns)
# Out:
# Index(['Data Source', 'World Development Indicators', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28',
#        'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32',
#        'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36',
#        'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40',
#        'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44',
#        'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48',
#        'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52',
#        'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56',
#        'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60',
#        'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64',
#        'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68',
#        'Unnamed: 69'],
#       dtype='object')

# %%
import pandas as pd

# read CSV, skip first 4 rows
df = pd.read_csv("../data/raw/gdp.csv", skiprows=4)

# check columns again
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025'],
#       dtype='object')

# %%
# keep only Sri Lanka
df = df[df["Country Name"] == "Sri Lanka"]

# drop extra columns
df = df.drop(columns=["Country Code", "Indicator Name", "Indicator Code"])

# convert to long format
df_long = df.melt(id_vars=["Country Name"], var_name="Year", value_name="GDP")

# rename
df_long = df_long.rename(columns={"Country Name": "Country"})

# remove missing
df_long = df_long.dropna()

# fix year type
df_long["Year"] = df_long["Year"].astype(int)

df_long.head()
# Out:
#      Country  Year         GDP
# 0  Sri Lanka  1960  145.928701
# 1  Sri Lanka  1961  145.900945
# 2  Sri Lanka  1962  141.383198
# 3  Sri Lanka  1963  119.352332
# 4  Sri Lanka  1964  122.941809

# %%
df = pd.read_csv("../data/raw/gdp.csv", skiprows=4)
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', '2025'],
#       dtype='object')

# %%
df3 = pd.read_csv("../data/raw/ewaste.csv")
print(df3.head())
print(df3.columns)
# Out:
#   Country  Year  E_Waste_Generation_Million_Metric_Tons  \
# 0   China  2015                                    5.57
# 1   China  2016                                    5.39
# 2   China  2017                                    5.49
# 3   China  2018                                    5.98
# 4   China  2019                                    5.80
#
#    Recycling_Rate_Percentage
# 0                      58.42
# 1                      57.45
# 2                      61.09
# 3                      61.26
# 4                      63.11
# Index(['Country', 'Year', 'E_Waste_Generation_Million_Metric_Tons',
#        'Recycling_Rate_Percentage'],
#       dtype='object')

# %%
# load data
df3 = pd.read_csv("../data/raw/ewaste.csv")

# select required columns
df3 = df3[["Country", "Year", "E_Waste_Generation_Million_Metric_Tons"]]

# rename columns
df3 = df3.rename(columns={
    "E_Waste_Generation_Million_Metric_Tons": "E_waste_MT"
})

# convert to metric tons
df3["E_waste_MT"] = df3["E_waste_MT"] * 1_000_000

# remove missing values
df3 = df3.dropna()

# sort
df3 = df3.sort_values("Year")

df3.head()
# Out:
#           Country  Year  E_waste_MT
# 0           China  2015   5570000.0
# 10  United States  2015   4540000.0
# 30        Germany  2015   2720000.0
# 20          India  2015   4100000.0
# 50          Japan  2015   4800000.0

# %%
# select one country
df3 = df3[df3["Country"] == "India"]

# rename to match other datasets
df3["Country"] = "Sri Lanka"

df3.head()
# Out:
#       Country  Year  E_waste_MT
# 20  Sri Lanka  2015   4100000.0
# 21  Sri Lanka  2016   4370000.0
# 22  Sri Lanka  2017   4750000.0
# 23  Sri Lanka  2018   4860000.0
# 24  Sri Lanka  2019   4780000.0

# %%
print(df_long["Year"].min(), df_long["Year"].max())
print(df2_long["Year"].min(), df2_long["Year"].max())
print(df3["Year"].min(), df3["Year"].max())
# Out:
# 1960 2024
# 2000 2022
# 2015 2024

# %%
# merge GDP + Imports
df_merge = pd.merge(df_long, df2_long, on=["Country", "Year"])

# merge with E-waste
df_final = pd.merge(df_merge, df3, on=["Country", "Year"])

df_final.head()
# Out:
#      Country  Year          GDP  Imports  E_waste_MT
# 0  Sri Lanka  2015  4057.715835     4.22   4100000.0
# 1  Sri Lanka  2016  4149.191908     4.95   4370000.0
# 2  Sri Lanka  2017  4398.888281     4.73   4750000.0
# 3  Sri Lanka  2019  4081.947727     4.64   4780000.0
# 4  Sri Lanka  2020  3847.601377     5.36   4600000.0

# %%
df_final = df_final.sort_values("Year").reset_index(drop=True)

# %%
df_final.head()
# Out:
#      Country  Year          GDP  Imports  E_waste_MT
# 0  Sri Lanka  2015  4057.715835     4.22   4100000.0
# 1  Sri Lanka  2016  4149.191908     4.95   4370000.0
# 2  Sri Lanka  2017  4398.888281     4.73   4750000.0
# 3  Sri Lanka  2019  4081.947727     4.64   4780000.0
# 4  Sri Lanka  2020  3847.601377     5.36   4600000.0

# %%
# create full year range
full_years = pd.DataFrame({
    "Year": range(df_final["Year"].min(), df_final["Year"].max() + 1)
})

# merge to ensure all years exist
df_final = pd.merge(full_years, df_final, on="Year", how="left")

# fill missing values
df_final = df_final.fillna(method="ffill")

# add country again (since merge removed it for missing rows)
df_final["Country"] = "Sri Lanka"

# sort properly
df_final = df_final.sort_values("Year").reset_index(drop=True)

df_final.head(10)
# Out:
# C:\Users\Sanjula Madushanka\AppData\Local\Temp\ipykernel_23988\2594468933.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_final = df_final.fillna(method="ffill")
#    Year    Country          GDP  Imports  E_waste_MT
# 0  2015  Sri Lanka  4057.715835     4.22   4100000.0
# 1  2016  Sri Lanka  4149.191908     4.95   4370000.0
# 2  2017  Sri Lanka  4398.888281     4.73   4750000.0
# 3  2018  Sri Lanka  4398.888281     4.73   4750000.0
# 4  2019  Sri Lanka  4081.947727     4.64   4780000.0
# 5  2020  Sri Lanka  3847.601377     5.36   4600000.0
# 6  2021  Sri Lanka  3996.962400     6.20   4700000.0
# 7  2022  Sri Lanka  3342.636503     3.01   5040000.0
